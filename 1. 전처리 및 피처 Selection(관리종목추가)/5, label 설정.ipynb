# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/5. 이자보상배율 완료.csv",encoding='cp949')
df
# Out:
#            회사명  거래소코드        회계년도         상장일 상장폐지일  소속코드                 산업명  \
# 0     (주)CMG제약  58820  2011-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 1     (주)CMG제약  58820  2012-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 2     (주)CMG제약  58820  2013-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 3     (주)CMG제약  58820  2014-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 4     (주)CMG제약  58820  2015-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# ...        ...    ...         ...         ...   ...   ...                 ...
# 9852   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9853   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9854   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9855   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9856   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
#
# ...

# %%
df["label"] = 0
df[df["회사명"].str.contains("바른손")]
# Out:
#              회사명  거래소코드        회계년도         상장일 상장폐지일  소속코드  \
# 1383  (주)바른손이앤에이  35620  2011-12-01  1999-08-13   NaN     5
# 1384  (주)바른손이앤에이  35620  2012-12-01  1999-08-13   NaN     5
# 1385  (주)바른손이앤에이  35620  2013-12-01  1999-08-13   NaN     5
# 1386  (주)바른손이앤에이  35620  2014-12-01  1999-08-13   NaN     5
# 1387  (주)바른손이앤에이  35620  2015-12-01  1999-08-13   NaN     5
# 1388  (주)바른손이앤에이  35620  2016-12-01  1999-08-13   NaN     5
# 1389  (주)바른손이앤에이  35620  2017-12-01  1999-08-13   NaN     5
# 1390  (주)바른손이앤에이  35620  2018-12-01  1999-08-13   NaN     5
# 1391  (주)바른손이앤에이  35620  2019-12-01  1999-08-13   NaN     5
# 1392  (주)바른손이앤에이  35620  2020-12-01  1999-08-13   NaN     5
#
#                         산업명  매출액증가율  유형자산증가율  재고자산증가율  ...  당좌자산회전률  \
# 1383    영상ㆍ오디오 기록물 제작 및 배급업    0.15     8.84      0.0  ...     1.74
# 1384    영상ㆍ오디오 기록물 제작 및 배급업  -34.95   385.56      0.0  ...     0.91
# 1385    영상ㆍ오디오 기록물 제작 및 배급업  -35.60    59.61      0.0  ...     0.62
# ...

# %% [markdown]
# # 관리 종목 지정 확인 하기

# %%
df_20121 = pd.read_csv("./data/2012년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20122 = pd.read_csv("./data/2012년 관리종목 지정 종목 2.csv", encoding='cp949')
df_2012 = pd.concat([df_20121,df_20122])
df_2012.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2012 = df_2012["거래소코드"].unique().tolist()

len(df_all_2012)
# Out:
# 77

# %%
all_list = []
for i in df_all_2012:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2012[df_2012["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)

# %%
all_df[all_df["공시제목"].str.contains("지정")]
# Out:
#      번호                시간     회사명   거래소코드                           공시제목  \
# 0    70  2012-03-30 19:16   폴리플러스   65610          관리종목지정사유추가(사업보고서 미제출)
# 13   57  2012-03-22 21:10   폴리플러스   65610              관리종목지정(상장폐지사유 발생)
# 76   94  2012-04-09 20:13   폴리플러스   65610  관리종목지정사유일부해제(사업보고서 미제출 사유 해소)
# 1    69  2012-03-30 19:16    미주제강    2670     관리종목지정사유추가(사업보고서 미제출 외 1건)
# 2    68  2012-03-30 18:04    미주제강    2670         관리종목지정사유추가(회생절차 개시신청 )
# ..  ...               ...     ...     ...                            ...
# 52  118  2012-08-14 20:04  티에스넥스젠   43220                         관리종목지정
# 54  116  2012-08-13 18:41  오리엔탈정공   14940                         관리종목지정
# 56  114  2012-08-01 18:15    금강제강  105070               관리종목지정(상장폐지사유발생)
# 60  110  2012-06-20 19:01    해피드림   65180             관리종목지정(상장폐지사유 발생 )
# 73   97  2012-04-13 18:26   JH코오스   65310                         관리종목지정
#
#         제출인
# 0   코스닥시장본부
# 13  코스닥시장본부
# 76  코스닥시장본부
# 1   코스닥시장본부
# 2   코스닥시장본부
# ...

# %%
list_2012 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
list_2012
# Out:
# [65610,
#  2670,
#  73130,
#  67130,
#  36920,
#  42340,
#  45260,
#  56710,
#  15390,
#  94700,
#  42820,
#  38320,
#  46400,
#  52350,
#  33280,
#  7150,
#  60240,
#  60230,
#  31390,
#  38120,
#  25920,
#  39530,
#  35450,
#  13780,
#  64090,
#  66690,
#  68150,
#  95700,
#  38720,
#  50470,
#  65500,
#  89480,
#  37760,
#  98400,
#  56010,
#  53040,
#  60910,
#  40740,
#  42510,
#  50050,
#  53810,
#  34010,
#  26250,
#  66060,
#  7390,
#  37950,
#  45050,
#  66430,
#  54180,
#  71660,
#  91690,
#  52650,
#  53870,
#  68420,
#  19260,
#  9010,
#  43220,
#  14940,
#  105070,
#  65180,
#  65310]

# %%
index_list_2012 = []
del_list_2012=[]
for i in list_2012:
    a = df[df["거래소코드"]==i]
    num = a[a["회계년도"]=="2011-12-01"].index
    num_list = a[a["회계년도"]!="2011-12-01"].index
    index_list_2012.append(num)
    del_list_2012.append(num_list)

# %%
del_list_2012
# Out:
# [Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([5168], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([7585, 7586], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099], dtype='int64'),
#  Index([8039, 8040, 8041, 8042, 8043, 8044, 8045, 8046, 8047], dtype='int64'),
#  Index([401, 402, 403, 404, 405, 406, 407, 408, 409], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([8753], dtype='int64'),
#  Index([2515, 2516], dtype='int64'),
#  Index([5166], dtype='int64'),
#  Index([2874], dtype='int64'),
#  Index([3480, 3481, 3482, 3483, 3484, 3485, 3486, 3487, 3488], dtype='int64'),
#  Index([], dtype='int64'),
# ...

# %%
for i in index_list_2012:
    df.loc[i,"label"] = 1

# %%
for i in del_list_2012:
    for j in i:
        df.drop(j, inplace=True)

df.reset_index(drop=True,inplace=True)

# %%
df_20131 = pd.read_csv("./data/2013년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20132 = pd.read_csv("./data/2013년 관리종목 지정 종목 2.csv", encoding='cp949')
df_2013 = pd.concat([df_20131,df_20132])
df_2013.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2013 = df_2013["거래소코드"].unique().tolist()

len(df_all_2013)
# Out:
# 73

# %%
all_list = []
for i in df_all_2013:
    a = len(df[df["거래소코드"]==i])
    if a >= 1 and  df[df["거래소코드"]==i]["label"].sum()<1:
        b = df_2013[df_2013["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)    
all_df[all_df["공시제목"].str.contains("지정")]
# Out:
#      번호                시간      회사명   거래소코드  \
# 0   141  2013-12-31 17:31    태산엘시디   36210
# 28  113  2013-08-28 18:09    태산엘시디   36210
# 1   140  2013-12-31 16:56     쌍용건설   12650
# 16  125  2013-09-09 18:25     쌍용건설   12650
# 1    40  2013-03-21 22:20     쌍용건설   12650
# 2   139  2013-12-20 18:56    테라리소스   53320
# 3   138  2013-12-19 18:19     엠텍비젼   74000
# 5   136  2013-11-18 18:26     엠텍비젼   74000
# 9   132  2013-10-31 18:18     엠텍비젼   74000
# 20  121  2013-08-29 20:36     엠텍비젼   74000
# 61   80  2013-04-11 18:21     엠텍비젼   74000
# 76   65  2013-04-01 22:11     엠텍비젼   74000
# 0    41  2013-03-21 22:20     엠텍비젼   74000
# 35    6  2013-01-30 16:44     엠텍비젼   74000
# 4   137  2013-11-29 19:01      글로본   19660
# 44   97  2013-06-20 19:45      글로본   19660
# 32  109  2013-08-09 18:03  한국테크놀로지   53590
# 8   133  2013-11-07 18:41   이매진아시아   36260
# 11  130  2013-10-01 16:49    삼표시멘트   38500
# 12  129  2013-09-30 18:42      HLB   28300
# 31  110  2013-08-09 18:04      HLB   28300
# ...

# %%
list_2013 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
list_2013
# Out:
# [36210,
#  12650,
#  53320,
#  74000,
#  19660,
#  53590,
#  36260,
#  38500,
#  28300,
#  26260,
#  41060,
#  4790,
#  56810,
#  49000,
#  40670,
#  38880,
#  42040,
#  131370,
#  131030,
#  33430,
#  123420,
#  90120,
#  89850,
#  88700,
#  123840,
#  46840,
#  110310,
#  33550,
#  71530,
#  28090,
#  42940,
#  51710]

# %%
index_list_2013 = []
del_list_2013=[]
for i in list_2013:
    a = df[df["거래소코드"]==i]
    num = a[a["회계년도"]=="2012-12-01"].index
    num_list = a[a["회계년도"]!="2012-12-01"].index
    index_list_2013.append(num)
    del_list_2013.append(num_list)
index_list_2013
# Out:
# [Index([9276], dtype='int64'),
#  Index([8010], dtype='int64'),
#  Index([5901], dtype='int64'),
#  Index([8487], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([4452], dtype='int64'),
#  Index([1751], dtype='int64'),
#  Index([8334], dtype='int64'),
#  Index([4126], dtype='int64'),
#  Index([2591], dtype='int64'),
#  Index([1032], dtype='int64'),
#  Index([4153], dtype='int64'),
#  Index([3739], dtype='int64'),
#  Index([3913], dtype='int64'),
#  Index([2724], dtype='int64'),
#  Index([5512], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([7477], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([8911], dtype='int64'),
#  Index([8742], dtype='int64'),
#  Index([1124], dtype='int64'),
#  Index([], dtype='int64'),
#  Index([4810], dtype='int64'),
#  Index([1272], dtype='int64'),
#  Index([1074], dtype='int64'),
#  Index([4318], dtype='int64'),
#  Index([328], dtype='int64'),
#  Index([1809], dtype='int64'),
# ...

# %%
for i in index_list_2013:
    df.loc[i,"label"] = 1

# %%
for i in del_list_2013:
    for j in i:
        df.drop(j, inplace=True)

# %%
df_2014 = pd.read_csv("./data/2014년 관리종목 지정 종목.csv",encoding='cp949')
df_2014.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2014 = df_2014["거래소코드"].unique().tolist()

len(df_all_2014)
# Out:
# 45

# %%
all_list = []
for i in df_all_2014:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2014[df_2014["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)

# %%
all_df[all_df["공시제목"].str.contains("지정")]
# Out:
#     번호                시간      회사명   거래소코드  \
# 3   80  2014-12-05 18:10   에이스하이텍   71930
# 2   81  2014-12-10 18:48     터보테크   32420
# 11  72  2014-09-11 19:52     터보테크   32420
# 13  70  2014-08-29 20:13     터보테크   32420
# 64  19  2014-03-20 19:50     터보테크   32420
# 4   79  2014-11-24 18:12    승화프리텍  111610
# 26  57  2014-08-07 18:48    승화프리텍  111610
# 5   78  2014-11-19 17:26  영진코퍼레이션   53330
# 7   76  2014-10-30 18:24  영진코퍼레이션   53330
# 8   75  2014-10-07 18:57    울트라건설    4320
# 15  68  2014-08-29 19:08     제이웨이   58420
# 63  20  2014-03-20 19:50    골드앤에스   35290
# 20  63  2014-08-26 17:50    태창파로스   39850
# 21  62  2014-08-14 19:36     뉴아세아   13340
# 27  56  2014-07-29 20:16     뉴아세아   13340
# 34  49  2014-04-28 19:16     뉴아세아   13340
# 37  46  2014-04-10 19:58     뉴아세아   13340
# 45  38  2014-03-31 21:28     뉴아세아   13340
# 77   6  2014-03-03 18:58     뉴아세아   13340
# 22  61  2014-08-14 19:10    플레이위드   23770
# 55  28  2014-03-21 21:05    플레이위드   23770
# ...

# %%
list_2014 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
index_list_2014 = []
del_list_2014=[]
for i in list_2014:
    a = df[df["거래소코드"]== i]
    num = a[a["회계년도"]=="2013-12-01"].index
    num_list = a[a["회계년도"]!="2013-12-01"].index
    index_list_2014.append(num)
    del_list_2014.append(num_list)

# %%
for i in index_list_2014:
    df.loc[i,"label"] = 1
for i in del_list_2014:
    for j in i:
        df.drop(j, inplace=True)

# %%
df[df["label"]==1]
# Out:
#             회사명  거래소코드        회계년도         상장일       상장폐지일  소속코드  \
# 58     (주)골드앤에스  35290  2013-12-01  1999-12-07         NaN     5
# 102       (주)광무  29480  2013-12-01  1996-08-27         NaN     5
# 328     (주)네오퍼플  28090  2012-12-01  1996-11-29  2013-05-03     4
# 396     (주)녹십자셀  31390  2011-12-01  1998-09-25  2021-11-17     4
# 518       (주)대국  42340  2011-12-01  2000-06-22  2012-04-13     4
# ...         ...    ...         ...         ...         ...   ...
# 8733     유니슨(주)  18000  2013-12-01  1996-01-10         NaN     5
# 8742   유비벨록스(주)  89850  2012-12-01  2010-06-18         NaN     5
# 8786  이디디컴퍼니(주)  52650  2011-12-01  2001-12-18  2013-04-12     4
# 8911    잘만테크(주)  90120  2012-12-01  2007-05-22  2015-05-13     4
# 9276   태산엘시디(주)  36210  2012-12-01  1999-11-16  2014-04-11     4
#
#                                  산업명  매출액증가율  유형자산증가율  재고자산증가율  ...  당좌자산회전률  \
# 58                               출판업   -9.89  2289.15    18.51  ...     2.16
# ...

# %%
df_20151 = pd.read_csv("./data/2015년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20152 = pd.read_csv("./data/2015년 관리종목 지정 종목 2.csv", encoding='cp949')
df_2015 = pd.concat([df_20151,df_20152])
df_2015.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2015 = df_2015["거래소코드"].unique().tolist()

len(df_all_2015)
# Out:
# 56

# %%
all_list = []
for i in df_all_2015:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2015[df_2015["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)

# %%
list_2015 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
index_list_2015 = []
del_list_2015=[]
for i in list_2015:
    a = df[df["거래소코드"]== i]
    num = a[a["회계년도"]=="2014-12-01"].index
    num_list = a[a["회계년도"]!="2014-12-01"].index
    index_list_2015.append(num)
    del_list_2015.append(num_list)

# %%
for i in index_list_2015:
    df.loc[i,"label"] = 1
for c in del_list_2015:
    for j in c:
        df.drop(j, inplace=True)

# %%
df.loc[1380:1400]
# Out:
#                회사명   거래소코드        회계년도         상장일       상장폐지일  소속코드  \
# 1380      (주)바이오니아   64550  2013-12-01  2005-12-29         NaN     5
# 1381      (주)바이오니아   64550  2014-12-01  2005-12-29         NaN     5
# 1382      (주)바이오니아   64550  2015-12-01  2005-12-29         NaN     5
# 1383      (주)바이오니아   64550  2016-12-01  2005-12-29         NaN     5
# 1384      (주)바이오니아   64550  2017-12-01  2005-12-29         NaN     5
# 1385      (주)바이오니아   64550  2018-12-01  2005-12-29         NaN     5
# 1386      (주)바이오니아   64550  2019-12-01  2005-12-29         NaN     5
# 1387      (주)바이오니아   64550  2020-12-01  2005-12-29         NaN     5
# 1388  (주)바이오로그디바이스  208710  2016-12-01  2014-12-24         NaN     5
# 1389  (주)바이오로그디바이스  208710  2017-12-01  2014-12-24         NaN     5
# 1390  (주)바이오로그디바이스  208710  2018-12-01  2014-12-24         NaN     5
# 1391  (주)바이오로그디바이스  208710  2019-12-01  2014-12-24         NaN     5
# 1392  (주)바이오로그디바이스  208710  2020-12-01  2014-12-24         NaN     5
# ...

# %%
df[df["label"]==1]
# Out:
#             회사명  거래소코드        회계년도         상장일       상장폐지일  소속코드  \
# 58     (주)골드앤에스  35290  2013-12-01  1999-12-07         NaN     5
# 102       (주)광무  29480  2013-12-01  1996-08-27         NaN     5
# 273     (주)네오리진  94860  2014-12-01  2007-04-16         NaN     5
# 328     (주)네오퍼플  28090  2012-12-01  1996-11-29  2013-05-03     4
# 396     (주)녹십자셀  31390  2011-12-01  1998-09-25  2021-11-17     4
# ...         ...    ...         ...         ...         ...   ...
# 8742   유비벨록스(주)  89850  2012-12-01  2010-06-18         NaN     5
# 8786  이디디컴퍼니(주)  52650  2011-12-01  2001-12-18  2013-04-12     4
# 8911    잘만테크(주)  90120  2012-12-01  2007-05-22  2015-05-13     4
# 9276   태산엘시디(주)  36210  2012-12-01  1999-11-16  2014-04-11     4
# 9664    현진소재(주)  53660  2014-12-01  2002-02-15  2022-04-26     4
#
#                                  산업명  매출액증가율  유형자산증가율  재고자산증가율  ...  당좌자산회전률  \
# 58                               출판업   -9.89  2289.15    18.51  ...     2.16
# ...

# %%
df_20161 = pd.read_csv("./data/2016년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20162 = pd.read_csv("./data/2016년 관리종목 지정 종목 2.csv", encoding='cp949')
df_2016 = pd.concat([df_20161,df_20162])
df_2016.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2016 = df_2016["거래소코드"].unique().tolist()

len(df_all_2016)
# Out:
# 53

# %%
all_list = []
for i in df_all_2016:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2016[df_2016["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)

# %%
list_2016 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
index_list_2016 = []
del_list_2016=[]
for i in list_2016:
    a = df[df["거래소코드"]== i]
    num = a[a["회계년도"]=="2015-12-01"].index
    num_list = a[a["회계년도"]!="2015-12-01"].index
    index_list_2016.append(num)
    del_list_2016.append(num_list)

# %%
for i in index_list_2016:
    df.loc[i,"label"] = 1
for c in del_list_2016:
    for j in c:
        df.drop(j, inplace=True)

# %%
df_20171 = pd.read_csv("./data/2017년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20172 = pd.read_csv("./data/2017년 관리종목 지정 종목 2.csv", encoding='cp949')
df_2017 = pd.concat([df_20171,df_20172])
df_2017.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2017 = df_2017["거래소코드"].unique().tolist()

len(df_all_2017)
# Out:
# 31

# %%
all_list = []
for i in df_all_2017:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2017[df_2017["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)

# %%
list_2017 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
index_list_2017 = []
del_list_2017=[]
for i in list_2017:
    a = df[df["거래소코드"]== i]
    num = a[a["회계년도"]=="2016-12-01"].index
    num_list = a[a["회계년도"]!="2016-12-01"].index
    index_list_2017.append(num)
    del_list_2017.append(num_list)

# %%
for i in index_list_2017:
    df.loc[i,"label"] = 1
for c in del_list_2017:
    for j in c:
        df.drop(j, inplace=True)

# %%
df_20181 = pd.read_csv("./data/2018년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20182 = pd.read_csv("./data/2018년 관리종목 지정 종목 2.csv", encoding='cp949')
df_2018 = pd.concat([df_20181,df_20182])
df_2018.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2018 = df_2018["거래소코드"].unique().tolist()

len(df_all_2018)
# Out:
# 90

# %%
all_list = []
for i in df_all_2018:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2018[df_2018["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)

# %%
list_2018 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
index_list_2018 = []
del_list_2018=[]
for i in list_2018:
    a = df[df["거래소코드"]== i]
    num = a[a["회계년도"]=="2017-12-01"].index
    num_list = a[a["회계년도"]!="2017-12-01"].index
    index_list_2018.append(num)
    del_list_2018.append(num_list)

# %%
for i in index_list_2018:
    df.loc[i,"label"] = 1
for c in del_list_2018:
    for j in c:
        df.drop(j, inplace=True)

# %%
df_20191 = pd.read_csv("./data/2019년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20192 = pd.read_csv("./data/2019년 관리종목 지정 종목 2.csv", encoding='cp949')
df_20193 = pd.read_csv("./data/2019년 관리종목 지정 종목 3.csv", encoding='cp949')
df_2019 = pd.concat([df_20191,df_20192,df_20193])
df_2019.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2019 = df_2019["거래소코드"].unique().tolist()

len(df_all_2019)

all_list = []
for i in df_all_2019:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2019[df_2019["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)    

list_2019 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
index_list_2019 = []
del_list_2019=[]
for i in list_2019:
    a = df[df["거래소코드"]== i]
    num = a[a["회계년도"]=="2018-12-01"].index
    num_list = a[a["회계년도"]!="2018-12-01"].index
    index_list_2019.append(num)
    del_list_2019.append(num_list)

for i in index_list_2019:
    df.loc[i,"label"] = 1
for c in del_list_2019:
    for j in c:
        df.drop(j, inplace=True)

# %%
df_20201 = pd.read_csv("./data/2020년 관리종목 지정 종목 1.csv", encoding='cp949')
df_20202 = pd.read_csv("./data/2020년 관리종목 지정 종목 2.csv", encoding='cp949')
df_2020 = pd.concat([df_20201,df_20202])
df_2020.columns =['번호', '시간', '회사명', '거래소코드', '공시제목', '제출인']
df_all_2020 = df_2020["거래소코드"].unique().tolist()

len(df_all_2020)

all_list = []
for i in df_all_2020:
    a = len(df[df["거래소코드"]== i])
    if a >= 1 and  df[df["거래소코드"]== i]["label"].sum()<1:
        b = df_2020[df_2020["거래소코드"]==i]
        all_list.append(b)

all_df = pd.concat(all_list)    

list_2020 = all_df[all_df["공시제목"].str.contains("지정")]["거래소코드"].unique().tolist()
index_list_2020 = []
del_list_2020=[]
for i in list_2020:
    a = df[df["거래소코드"]== i]
    num = a[a["회계년도"]=="2019-12-01"].index
    num_list = a[a["회계년도"]!="2019-12-01"].index
    index_list_2020.append(num)
    del_list_2020.append(num_list)
    
for i in index_list_2020:
    df.loc[i,"label"] = 1
for c in del_list_2020:
    for j in c:
        df.drop(j, inplace=True)

# %%
df.reset_index(drop=True,inplace=True)
# Out:
#            회사명  거래소코드        회계년도         상장일 상장폐지일  소속코드                 산업명  \
# 0     (주)CMG제약  58820  2011-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 1     (주)CMG제약  58820  2012-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 2     (주)CMG제약  58820  2013-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 3     (주)CMG제약  58820  2014-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 4     (주)CMG제약  58820  2015-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# ...        ...    ...         ...         ...   ...   ...                 ...
# 8234   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 8235   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 8236   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 8237   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 8238   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
#
# ...

# %%
len(df[df["label"]==0])
len(df[df["label"]==1])
# Out:
# 273

# %%
df.reset_index(inplace=True)
df_label = df[['index','회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '소속코드']]

# %%
df_label= df_label[df_label['소속코드']==4]
df_label= df_label.groupby('회사명')['index'].apply(list)

# %%
df_label = pd.DataFrame(df_label)
df_label
# Out:
#                                                        index
# 회사명
# (주)금빛      [129, 130, 131, 132, 133, 134, 135, 136, 137, ...
# (주)네오퍼플                                                [269]
# (주)넥스지                                                 [288]
# (주)녹십자셀                                                [323]
# (주)뉴로스              [352, 353, 354, 355, 356, 357, 358, 359]
# ...                                                      ...
# 참존글로벌(주)                                              [7706]
# 태산엘시디(주)                                              [7840]
# 한솔신텍(주)                                               [8073]
# 한일네트웍스(주)  [8101, 8102, 8103, 8104, 8105, 8106, 8107, 810...
# 현진소재(주)                                               [8198]
#
# [163 rows x 1 columns]

# %%
for j in df_label.index:
    for i in df.index:
        if df_label["index"][j][-1] == i:
            df.loc[i,'label'] = 1
df['label'] = df["label"].fillna(0)

# %%
defalut = df[~df["상장폐지일"].isnull()]
defalut
# Out:
#       index        회사명  거래소코드        회계년도         상장일       상장폐지일  소속코드  \
# 129     129      (주)금빛  45890  2011-12-01  2005-11-28  2021-12-20     4
# 130     130      (주)금빛  45890  2012-12-01  2005-11-28  2021-12-20     4
# 131     131      (주)금빛  45890  2013-12-01  2005-11-28  2021-12-20     4
# 132     132      (주)금빛  45890  2014-12-01  2005-11-28  2021-12-20     4
# 133     133      (주)금빛  45890  2015-12-01  2005-11-28  2021-12-20     4
# ...     ...        ...    ...         ...         ...         ...   ...
# 8107   8107  한일네트웍스(주)  46110  2017-12-01  2006-01-20  2022-10-05     4
# 8108   8108  한일네트웍스(주)  46110  2018-12-01  2006-01-20  2022-10-05     4
# 8109   8109  한일네트웍스(주)  46110  2019-12-01  2006-01-20  2022-10-05     4
# 8110   8110  한일네트웍스(주)  46110  2020-12-01  2006-01-20  2022-10-05     4
# 8198   8198    현진소재(주)  53660  2014-12-01  2002-02-15  2022-04-26     4
#
#                            산업명  매출액증가율  유형자산증가율  ...  당좌자산회전률      부가가치  \
# ...

# %%
drop_index=defalut[defalut['label']==0].index
drop_index
# Out:
# Index([ 129,  130,  131,  132,  133,  134,  135,  136,  137,  352,
#        ...
#        7557, 8101, 8102, 8103, 8104, 8105, 8106, 8107, 8108, 8109],
#       dtype='int64', length=106)

# %%
df.drop(drop_index, inplace=True)

# %%
df.columns
# Out:
# Index(['index', '회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '소속코드', '산업명',
#        '매출액증가율', '유형자산증가율', '재고자산증가율', '비유동자산증가율', '유동자산증가율', '자기자본증가율',
#        '총자본증가율', '순이익증가율', '매출액총이익률', '매출액순이익률', '자기자본순이익률', '총자본사업이익률',
#        '총자본순이익률', '1주당매출액', '1주당순이익', '유동비율', '당좌비율', '현금비율', '순운전자본비율',
#        '부채비율', '이자보상배율이자비용', '비유동비율', '유동자산구성비율', '자기자본구성비율', '자기자본배율',
#        '총자본회전률', '자기자본회전률', '비유동자산회전률', '재고자산회전률', '매출채권회전률', '매입채무회전률',
#        '매입채무회전기간', '재고자산회전기간', '매출채권회전기간', '1회전기간', '운전자본회전률', '순운전자본회전률',
#        '유형자산회전율', '유동자산회전률', '당좌자산회전률', '부가가치', '총자본투자효율', '설비투자효율', '기계투자효율',
#        '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'label'],
#       dtype='object')

# %%
df.drop('index',axis=1,inplace=True)

# %%
df["label"].value_counts()
# Out:
# label
# 0    7831
# 1     302
# Name: count, dtype: int64

# %%
df.to_csv("./data/5. label 지정 완료.csv", encoding= 'cp949',index=False)

# %% [markdown]
# ### 총데이터 8133 부도데이터 302 일반데이터 7831
