# %% [markdown]
# 데이터불러오기

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("raw_data.csv",index_col=0)
df.reset_index(drop=True,inplace=True)
df.head(10)
# Out:
#         회사명  거래소코드        회계년도  총자본순이익률  매출액증가율  자기자본순이익률  매출액순이익률     유동비율  \
# 0  (주)CMG제약  58820  2011-12-01    -5.58   56.40     -8.28    -8.50   200.97
# 1  (주)CMG제약  58820  2012-12-01   -15.78   -8.43    -26.84   -40.97   693.49
# 2  (주)CMG제약  58820  2013-12-01     0.52   25.51      0.74     1.45   694.71
# 3  (주)CMG제약  58820  2014-12-01     0.28   11.52      0.32     0.69   324.58
# 4  (주)CMG제약  58820  2015-12-01    -6.37   18.85     -7.62   -13.50   296.85
# 5  (주)CMG제약  58820  2016-12-01     2.06   21.92      2.34     5.24   862.15
# 6  (주)CMG제약  58820  2017-12-01     2.57   25.98      2.85     6.83   746.28
# 7  (주)CMG제약  58820  2018-12-01     5.42   20.05      6.01    12.16   957.86
# 8  (주)CMG제약  58820  2019-12-01     1.99   17.56      2.15     5.20  1618.07
# 9  (주)CMG제약  58820  2020-12-01     0.11    9.96      0.12     0.33  1069.54
#
#    자기자본구성비율  총자본회전률  ...  설비투자효율_비율_변동성_차이  설비투자효율_비율_변동성_비율  \
# 0     66.05    0.66  ...               NaN               NaN
# 1     55.32    0.39  ...               NaN               NaN
# 2     87.63    0.36  ...         26.877886        -28.233879
# 3     84.39    0.40  ...        -26.473302         -0.019833
# 4     82.80    0.47  ...          0.155301          0.698342
# 5     91.10    0.39  ...          1.933254         -4.377262
# 6     89.39    0.38  ...         -1.211669          0.230065
# 7     90.91    0.45  ...         -0.110146          0.695780
# 8     93.71    0.38  ...         -0.173326          0.311964
# 9     92.72    0.33  ...         -0.134260         -0.708400
#
#    순이익증가율_비율_변동성_차이  순이익증가율_비율_변동성_비율  Top10Gap_비율_변동성_차이  Top10Gap_비율_변동성_비율  \
# 0               NaN               NaN                 NaN                 NaN
# 1               NaN               NaN           -0.372403            2.827957
# 2               NaN               NaN            0.595115           -0.032953
# 3               NaN               NaN           -0.008762            0.538462
# 4               inf          0.000000           -0.242792          -22.750000
# 5               NaN               NaN            0.307780           -0.323391
# 6               NaN               NaN            0.018620            1.247573
# 7              -inf          0.000000            0.104054            2.108949
# 8         -2.214474         -1.845024           -0.125230            0.367159
# 9          2.306704         -0.606221           -0.068639            0.055276
#
#    AverageGap_비율_변동성_차이  AverageGap_비율_변동성_비율  KOSDAQ_변동성_Top10Gap  \
# 0                   NaN                   NaN             -130.906
# 1             11.809568              2.827957             -141.106
# 2            -18.872152             -0.032953             -124.806
# 3              0.277872              0.538462             -125.046
# 4              7.699375            -22.750000             -131.696
# 5             -9.760260             -0.323391             -123.266
# 6             -0.590478              1.247573             -122.756
# 7             -3.299732              2.108949             -119.906
# 8              3.971257              0.367159             -123.336
# 9              2.176665              0.055276             -125.216
#
#    KOSDAQ_변동성_Top10Gap_비율
# 0               -0.044524
# 1               -0.125912
# 2                0.004149
# 3                0.002234
# 4               -0.050827
# 5                0.016437
# 6                0.020507
# 7                0.043247
# 8                0.015879
# 9                0.000878
#
# [10 rows x 73 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9362 entries, 0 to 9361
# Data columns (total 73 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   회사명                     9362 non-null   object
#  1   거래소코드                   9362 non-null   int64
#  2   회계년도                    9362 non-null   object
#  3   총자본순이익률                 9362 non-null   float64
#  4   매출액증가율                  9362 non-null   float64
#  5   자기자본순이익률                9362 non-null   float64
#  6   매출액순이익률                 9362 non-null   float64
#  7   유동비율                    9362 non-null   float64
#  8   자기자본구성비율                9362 non-null   float64
#  9   총자본회전률                  9362 non-null   float64
#  10  자기자본회전률                 9362 non-null   float64
#  11  총자본투자효율                 9362 non-null   float64
#  12  설비투자효율                  9362 non-null   float64
#  13  순이익증가율                  9362 non-null   float64
#  14  label                   9362 non-null   float64
#  15  매출액증가율_차이               7954 non-null   float64
#  16  매출액증가율_비율               7950 non-null   float64
#  17  자기자본순이익률_차이             7954 non-null   float64
#  18  자기자본순이익률_비율             7949 non-null   float64
#  19  매출액순이익률_차이              7954 non-null   float64
#  20  매출액순이익률_비율              7950 non-null   float64
#  21  유동비율_차이                 7954 non-null   float64
#  22  유동비율_비율                 7954 non-null   float64
#  23  자기자본구성비율_차이             7954 non-null   float64
#  24  자기자본구성비율_비율             7954 non-null   float64
#  25  총자본회전률_차이               7954 non-null   float64
#  26  총자본회전률_비율               7946 non-null   float64
#  27  자기자본회전률_차이              7954 non-null   float64
#  28  자기자본회전률_비율              7939 non-null   float64
#  29  총자본투자효율_차이              7954 non-null   float64
#  30  총자본투자효율_비율              7954 non-null   float64
#  31  설비투자효율_차이               7954 non-null   float64
#  32  설비투자효율_비율               7949 non-null   float64
#  33  순이익증가율_차이               7954 non-null   float64
#  34  순이익증가율_비율               4986 non-null   float64
#  35  Top10Gap_차이             9362 non-null   float64
#  36  Top10Gap_비율             9362 non-null   float64
#  37  AverageGap_차이           9362 non-null   float64
#  38  AverageGap_비율           9362 non-null   float64
#  39  유동비율_변동성_차이             9361 non-null   float64
#  40  유동비율_변동성_비율             9361 non-null   float64
#  41  자기자본구성비율_변동성_차이         9361 non-null   float64
#  42  자기자본구성비율_변동성_비율         9361 non-null   float64
#  43  매출액증가율_비율_변동성_차이        6790 non-null   float64
#  44  매출액증가율_비율_변동성_비율        6790 non-null   float64
#  45  자기자본순이익률_비율_변동성_차이      6782 non-null   float64
#  46  자기자본순이익률_비율_변동성_비율      6782 non-null   float64
#  47  매출액순이익률_비율_변동성_차이       6787 non-null   float64
#  48  매출액순이익률_비율_변동성_비율       6787 non-null   float64
#  49  유동비율_차이_변동성_차이          6792 non-null   float64
#  50  유동비율_차이_변동성_비율          6792 non-null   float64
#  51  유동비율_비율_변동성_차이          6792 non-null   float64
#  52  유동비율_비율_변동성_비율          6792 non-null   float64
#  53  자기자본구성비율_차이_변동성_차이      6792 non-null   float64
#  54  자기자본구성비율_차이_변동성_비율      6792 non-null   float64
#  55  자기자본구성비율_비율_변동성_차이      6792 non-null   float64
#  56  자기자본구성비율_비율_변동성_비율      6792 non-null   float64
#  57  총자본회전률_비율_변동성_차이        6784 non-null   float64
#  58  총자본회전률_비율_변동성_비율        6769 non-null   float64
#  59  자기자본회전률_비율_변동성_차이       6771 non-null   float64
#  60  자기자본회전률_비율_변동성_비율       6763 non-null   float64
#  61  총자본투자효율_비율_변동성_차이       6792 non-null   float64
#  62  총자본투자효율_비율_변동성_비율       6792 non-null   float64
#  63  설비투자효율_비율_변동성_차이        6786 non-null   float64
#  64  설비투자효율_비율_변동성_비율        6786 non-null   float64
#  65  순이익증가율_비율_변동성_차이        3729 non-null   float64
#  66  순이익증가율_비율_변동성_비율        3729 non-null   float64
#  67  Top10Gap_비율_변동성_차이      9361 non-null   float64
#  68  Top10Gap_비율_변동성_비율      9361 non-null   float64
#  69  AverageGap_비율_변동성_차이    9361 non-null   float64
#  70  AverageGap_비율_변동성_비율    9361 non-null   float64
#  71  KOSDAQ_변동성_Top10Gap     9362 non-null   float64
#  72  KOSDAQ_변동성_Top10Gap_비율  9362 non-null   float64
# dtypes: float64(70), int64(1), object(2)
# memory usage: 5.2+ MB

# %%
#결측치 확인
missing_values = df.isnull().sum()
# 결측치가 있는 컬럼만 선택
missing_values[missing_values > 0]
# Out:
# 매출액증가율_차이               1408
# 매출액증가율_비율               1412
# 자기자본순이익률_차이             1408
# 자기자본순이익률_비율             1413
# 매출액순이익률_차이              1408
# 매출액순이익률_비율              1412
# 유동비율_차이                 1408
# 유동비율_비율                 1408
# 자기자본구성비율_차이             1408
# 자기자본구성비율_비율             1408
# 총자본회전률_차이               1408
# 총자본회전률_비율               1416
# 자기자본회전률_차이              1408
# 자기자본회전률_비율              1423
# 총자본투자효율_차이              1408
# 총자본투자효율_비율              1408
# 설비투자효율_차이               1408
# 설비투자효율_비율               1413
# 순이익증가율_차이               1408
# 순이익증가율_비율               4376
# 유동비율_변동성_차이                1
# 유동비율_변동성_비율                1
# 자기자본구성비율_변동성_차이            1
# 자기자본구성비율_변동성_비율            1
# 매출액증가율_비율_변동성_차이        2572
# 매출액증가율_비율_변동성_비율        2572
# 자기자본순이익률_비율_변동성_차이      2580
# 자기자본순이익률_비율_변동성_비율      2580
# 매출액순이익률_비율_변동성_차이       2575
# 매출액순이익률_비율_변동성_비율       2575
# 유동비율_차이_변동성_차이          2570
# 유동비율_차이_변동성_비율          2570
# 유동비율_비율_변동성_차이          2570
# 유동비율_비율_변동성_비율          2570
# 자기자본구성비율_차이_변동성_차이      2570
# 자기자본구성비율_차이_변동성_비율      2570
# 자기자본구성비율_비율_변동성_차이      2570
# 자기자본구성비율_비율_변동성_비율      2570
# 총자본회전률_비율_변동성_차이        2578
# 총자본회전률_비율_변동성_비율        2593
# 자기자본회전률_비율_변동성_차이       2591
# 자기자본회전률_비율_변동성_비율       2599
# 총자본투자효율_비율_변동성_차이       2570
# 총자본투자효율_비율_변동성_비율       2570
# 설비투자효율_비율_변동성_차이        2576
# 설비투자효율_비율_변동성_비율        2576
# 순이익증가율_비율_변동성_차이        5633
# 순이익증가율_비율_변동성_비율        5633
# Top10Gap_비율_변동성_차이         1
# Top10Gap_비율_변동성_비율         1
# AverageGap_비율_변동성_차이       1
# AverageGap_비율_변동성_비율       1
# dtype: int64

# %%
# "순이익증가율" 컬럼의 값 출력
profit_growth_rate = df['순이익증가율']
print(profit_growth_rate)
# Out:
# 0         0.00
# 1         0.00
# 2         0.00
# 3       -46.64
# 4         0.00
#          ...
# 9357     63.95
# 9358    -25.71
# 9359     -5.19
# 9360     14.78
# 9361    249.94
# Name: 순이익증가율, Length: 9362, dtype: float64

# %%
df['회계년도'] = pd.to_datetime(df['회계년도'])
df = df[df['회계년도'].dt.year != 2011]

# %%
df.isnull().sum()
# Out:
# 회사명                       0
# 거래소코드                     0
# 회계년도                      0
# 총자본순이익률                   0
# 매출액증가율                    0
#                          ..
# Top10Gap_비율_변동성_비율        0
# AverageGap_비율_변동성_차이      0
# AverageGap_비율_변동성_비율      0
# KOSDAQ_변동성_Top10Gap       0
# KOSDAQ_변동성_Top10Gap_비율    0
# Length: 73, dtype: int64

# %%
#결측치 확인
missing_values = df.isnull().sum()
# 결측치가 있는 컬럼만 선택
missing_values[missing_values > 0]
# Out:
# 매출액증가율_차이              673
# 매출액증가율_비율              677
# 자기자본순이익률_차이            673
# 자기자본순이익률_비율            678
# 매출액순이익률_차이             673
# 매출액순이익률_비율             677
# 유동비율_차이                673
# 유동비율_비율                673
# 자기자본구성비율_차이            673
# 자기자본구성비율_비율            673
# 총자본회전률_차이              673
# 총자본회전률_비율              681
# 자기자본회전률_차이             673
# 자기자본회전률_비율             688
# 총자본투자효율_차이             673
# 총자본투자효율_비율             673
# 설비투자효율_차이              673
# 설비투자효율_비율              678
# 순이익증가율_차이              673
# 순이익증가율_비율             3641
# 매출액증가율_비율_변동성_차이      1837
# 매출액증가율_비율_변동성_비율      1837
# 자기자본순이익률_비율_변동성_차이    1845
# 자기자본순이익률_비율_변동성_비율    1845
# 매출액순이익률_비율_변동성_차이     1840
# 매출액순이익률_비율_변동성_비율     1840
# 유동비율_차이_변동성_차이        1835
# 유동비율_차이_변동성_비율        1835
# 유동비율_비율_변동성_차이        1835
# 유동비율_비율_변동성_비율        1835
# 자기자본구성비율_차이_변동성_차이    1835
# 자기자본구성비율_차이_변동성_비율    1835
# 자기자본구성비율_비율_변동성_차이    1835
# 자기자본구성비율_비율_변동성_비율    1835
# 총자본회전률_비율_변동성_차이      1843
# 총자본회전률_비율_변동성_비율      1858
# 자기자본회전률_비율_변동성_차이     1856
# 자기자본회전률_비율_변동성_비율     1864
# 총자본투자효율_비율_변동성_차이     1835
# 총자본투자효율_비율_변동성_비율     1835
# 설비투자효율_비율_변동성_차이      1841
# 설비투자효율_비율_변동성_비율      1841
# 순이익증가율_비율_변동성_차이      4898
# 순이익증가율_비율_변동성_비율      4898
# dtype: int64

# %%
df.head(10)
# Out:
#          회사명  거래소코드       회계년도  총자본순이익률  매출액증가율  자기자본순이익률  매출액순이익률     유동비율  \
# 1   (주)CMG제약  58820 2012-12-01   -15.78   -8.43    -26.84   -40.97   693.49
# 2   (주)CMG제약  58820 2013-12-01     0.52   25.51      0.74     1.45   694.71
# 3   (주)CMG제약  58820 2014-12-01     0.28   11.52      0.32     0.69   324.58
# 4   (주)CMG제약  58820 2015-12-01    -6.37   18.85     -7.62   -13.50   296.85
# 5   (주)CMG제약  58820 2016-12-01     2.06   21.92      2.34     5.24   862.15
# 6   (주)CMG제약  58820 2017-12-01     2.57   25.98      2.85     6.83   746.28
# 7   (주)CMG제약  58820 2018-12-01     5.42   20.05      6.01    12.16   957.86
# 8   (주)CMG제약  58820 2019-12-01     1.99   17.56      2.15     5.20  1618.07
# 9   (주)CMG제약  58820 2020-12-01     0.11    9.96      0.12     0.33  1069.54
# 11   (주)ES큐브  50120 2012-12-01    -0.78    4.85      0.29    -0.64   472.77
#
#     자기자본구성비율  총자본회전률  ...  설비투자효율_비율_변동성_차이  설비투자효율_비율_변동성_비율  \
# 1      55.32    0.39  ...               NaN               NaN
# 2      87.63    0.36  ...         26.877886        -28.233879
# 3      84.39    0.40  ...        -26.473302         -0.019833
# 4      82.80    0.47  ...          0.155301          0.698342
# 5      91.10    0.39  ...          1.933254         -4.377262
# 6      89.39    0.38  ...         -1.211669          0.230065
# 7      90.91    0.45  ...         -0.110146          0.695780
# 8      93.71    0.38  ...         -0.173326          0.311964
# 9      92.72    0.33  ...         -0.134260         -0.708400
# 11     86.12    1.21  ...               NaN               NaN
#
#     순이익증가율_비율_변동성_차이  순이익증가율_비율_변동성_비율  Top10Gap_비율_변동성_차이  \
# 1                NaN               NaN           -0.372403
# 2                NaN               NaN            0.595115
# 3                NaN               NaN           -0.008762
# 4                inf          0.000000           -0.242792
# 5                NaN               NaN            0.307780
# 6                NaN               NaN            0.018620
# 7               -inf          0.000000            0.104054
# 8          -2.214474         -1.845024           -0.125230
# 9           2.306704         -0.606221           -0.068639
# 11               NaN               NaN            0.287335
#
#     Top10Gap_비율_변동성_비율  AverageGap_비율_변동성_차이  AverageGap_비율_변동성_비율  \
# 1             2.827957             11.809568              2.827957
# 2            -0.032953            -18.872152             -0.032953
# 3             0.538462              0.277872              0.538462
# 4           -22.750000              7.699375            -22.750000
# 5            -0.323391             -9.760260             -0.323391
# 6             1.247573             -0.590478              1.247573
# 7             2.108949             -3.299732              2.108949
# 8             0.367159              3.971257              0.367159
# 9             0.055276              2.176665              0.055276
# 11            0.090173             -9.111892              0.090173
#
#     KOSDAQ_변동성_Top10Gap  KOSDAQ_변동성_Top10Gap_비율
# 1              -141.106               -0.125912
# 2              -124.806                0.004149
# 3              -125.046                0.002234
# 4              -131.696               -0.050827
# 5              -123.266                0.016437
# 6              -122.756                0.020507
# 7              -119.906                0.043247
# 8              -123.336                0.015879
# 9              -125.216                0.000878
# 11             -126.106               -0.006224
#
# [10 rows x 73 columns]

# %%
df['회계년도'] = pd.to_datetime(df['회계년도'])
df1 = df[df['회계년도'].dt.year == 2012]

df1
# Out:
#              회사명   거래소코드       회계년도  총자본순이익률  매출액증가율  자기자본순이익률  매출액순이익률  \
# 1       (주)CMG제약   58820 2012-12-01   -15.78   -8.43    -26.84   -40.97
# 11       (주)ES큐브   50120 2012-12-01    -0.78    4.85      0.29    -0.64
# 21        (주)가비아   79940 2012-12-01    12.54   30.70     21.30    13.64
# 35      (주)강원에너지  114190 2012-12-01   -22.92  112.00    -37.55  -984.85
# 48    (주)고영테크놀러지   98460 2012-12-01    15.99   25.21     19.91    14.12
# ...          ...     ...        ...      ...     ...       ...      ...
# 9290   현대에이치티(주)   39010 2012-12-01    -0.16   -8.90     -0.31    -0.15
# 9300     현우산업(주)   92300 2012-12-01   -19.89   -4.30    -26.37   -78.28
# 9320     화일약품(주)   61250 2012-12-01     4.78   17.59      6.67     5.51
# 9336     휴림로봇(주)   90710 2012-12-01    -9.99  -38.14    -21.13   -16.49
# 9354     흥구석유(주)   24060 2012-12-01    19.79    4.39     23.71    35.84
#
#          유동비율  자기자본구성비율  총자본회전률  ...  설비투자효율_비율_변동성_차이  설비투자효율_비율_변동성_비율  \
# 1      693.49     55.32    0.39  ...               NaN               NaN
# 11     472.77     86.12    1.21  ...               NaN               NaN
# 21     215.35     69.15    0.92  ...               NaN               NaN
# 35    1175.05     48.43    0.02  ...               NaN               NaN
# 48     498.93     80.70    1.13  ...               NaN               NaN
# ...       ...       ...     ...  ...               ...               ...
# 9290   161.47     60.66    1.01  ...               NaN               NaN
# 9300   318.16     87.81    0.25  ...               NaN               NaN
# 9320   312.02     72.67    0.87  ...               NaN               NaN
# 9336   149.90     48.80    0.61  ...               NaN               NaN
# 9354   693.10     85.81    0.55  ...               NaN               NaN
#
#       순이익증가율_비율_변동성_차이  순이익증가율_비율_변동성_비율  Top10Gap_비율_변동성_차이  \
# 1                  NaN               NaN           -0.372403
# 11                 NaN               NaN            0.287335
# 21                 NaN               NaN            0.023366
# 35                 NaN               NaN            0.004016
# 48                 NaN               NaN           -0.140199
# ...                ...               ...                 ...
# 9290               NaN               NaN            0.455646
# 9300               NaN               NaN           -0.773284
# 9320               NaN               NaN            0.008762
# 9336               NaN               NaN           -0.468425
# 9354               NaN               NaN            0.059511
#
#       Top10Gap_비율_변동성_비율  AverageGap_비율_변동성_차이  AverageGap_비율_변동성_비율  \
# 1               2.827957             11.809568              2.827957
# 11              0.090173             -9.111892              0.090173
# 21              1.053782             -0.740992              1.053782
# 35              0.995224             -0.127358              0.995224
# 48              0.806354              4.445955              0.806354
# ...                  ...                   ...                   ...
# 9290            0.012658            -14.449353              0.012658
# 9300          -15.418605             24.522220            -15.418605
# 9320            1.052863             -0.277872              1.052863
# 9336           -3.517606             14.854584             -3.517606
# 9354            1.089758             -1.887215              1.089758
#
#       KOSDAQ_변동성_Top10Gap  KOSDAQ_변동성_Top10Gap_비율
# 1                -141.106               -0.125912
# 11               -126.106               -0.006224
# 21               -112.786                0.100059
# 35               -148.246               -0.182883
# 48               -109.336                0.127587
# ...                   ...                     ...
# 9290             -125.486               -0.001277
# 9300             -145.216               -0.158706
# 9320             -120.546                0.038141
# 9336             -135.316               -0.079712
# 9354             -105.536                0.157908
#
# [774 rows x 73 columns]
