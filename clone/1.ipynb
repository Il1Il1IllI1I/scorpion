# %%
import pandas as pd
import numpy as np

# 데이터 로드
df_1 = pd.read_csv('../데이터자료/0. 연결재무제표.csv', encoding='cp949')
df_2 = pd.read_csv('../데이터자료/0. 코스닥기업 연결재무제표.csv', encoding='cp949')

# 데이터 기본 정보 확인
df_2.info()
df_1.info()

# 상장폐지된 데이터 필터링
df_default = df_1[~df_1["상장폐지일"].isnull()]
print("상장폐지 기업 수:", len(df_default["회사명"].unique()))

# 2022년도 상장폐지 데이터 처리
df_default_2022 = df_default[df_default["상장폐지일"].str.contains('2022', na=False)]
for idx in df_default_2022.index:
    df_default.loc[idx, "상장폐지일"] = np.NaN
    df_default.loc[idx, "소속코드"] = 5

# 상장폐지 사유 데이터 처리
df_default_mod = pd.read_csv('../데이터자료/1. 상장폐지종목_사유등록.csv', encoding='cp949', index_col=0)
df = pd.concat([df_1, df_default_mod["상장폐지사유"]], axis=1)

# 코넥스, 합병 관련 데이터 제거
df = df[~df["상장폐지사유"].str.contains('코넥스', na=False)]
df = df[~df["상장폐지사유"].str.contains('합병', na=False)]

# 상장폐지 사유가 있는 데이터의 소속코드를 5로 수정
df.loc[~df["상장폐지사유"].isnull(), "소속코드"] = 5

# 날짜 데이터 처리 및 필터링
df["상장일"] = pd.to_datetime(df['상장일'])
df["상장폐지일"] = pd.to_datetime(df['상장폐지일'])
df["회계년도"] = pd.to_datetime(df["회계년도"])
df = df[df["상장폐지일"].dt.year >= 2011]

# 회계년도 기준 필터링
df["회계월"] = df["회계년도"].dt.month
df = df[df["회계월"] == 12]

# 외국계 기업 제거
df = df[df["거래소코드"] <= 900000]

# 중복 데이터 확인 및 제거
df["상장년도"] = df["상장일"].dt.year
df["회계년"] = df["회계년도"].dt.year
df["연차"] = df["회계년"] - df["상장년도"]
df = df[df["연차"] > 0]

b = df[["회사명", "거래소코드"]]
d = b.groupby("회사명")["거래소코드"].unique()
for company, codes in d.items():
    if len(codes) > 1:
        df = df[~df["거래소코드"].isin(codes)]

# 인덱스 초기화 및 최종 데이터 저장
df.reset_index(drop=True, inplace=True)
df.to_csv('../데이터자료/1. 상장폐지종목 정리끝.csv', encoding='cp949')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14347 entries, 0 to 14346
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   회사명                       14347 non-null  object
#  1   거래소코드                     14347 non-null  int64
#  2   회계년도                      14347 non-null  object
#  3   [제조]총자본증가율(IFRS연결)        9016 non-null   float64
#  4   [제조]유형자산증가율(IFRS연결)       9016 non-null   float64
#  5   [제조]비유동자산증가율(IFRS연결)      9016 non-null   float64
#  6   [제조]유동자산증가율(IFRS연결)       9016 non-null   float64
#  7   [제조]재고자산증가율(IFRS연결)       9016 non-null   float64
#  8   [제조]자기자본증가율(IFRS연결)       9016 non-null   float64
#  9   [제조]매출액증가율(IFRS연결)        9016 non-null   float64
#  10  [제조]순이익증가율(IFRS연결)        9016 non-null   float64
#  11  [제조]매출액총이익률(IFRS연결)       9016 non-null   float64
#  12  [제조]매출액순이익률(IFRS연결)       9016 non-null   float64
#  13  [제조]자기자본순이익률(IFRS연결)      9016 non-null   float64
#  14  [제조]총자본사업이익률(IFRS연결)      9016 non-null   float64
#  15  [제조]총자본순이익률(IFRS연결)       9016 non-null   float64
#  16  [제조]1주당매출액(IFRS연결)        9016 non-null   float64
#  17  [제조]1주당순이익(IFRS연결)        9016 non-null   float64
#  18  [제조]유동비율(IFRS연결)          9016 non-null   float64
#  19  [제조]당좌비율(IFRS연결)          9016 non-null   float64
#  20  [제조]현금비율(IFRS연결)          9016 non-null   float64
#  21  [제조]순운전자본비율(IFRS연결)       9016 non-null   float64
#  22  [제조]부채비율(IFRS연결)          9016 non-null   float64
#  23  [제조]이자보상배율(이자비용)(IFRS연결)  9016 non-null   float64
#  24  [제조]비유동비율(IFRS연결)         9016 non-null   float64
#  25  [제조]유동자산구성비율(IFRS연결)      9016 non-null   float64
#  26  [제조]자기자본구성비율(IFRS연결)      9016 non-null   float64
#  27  [제조]자기자본배율(IFRS연결)        9016 non-null   float64
#  28  [제조]총자본회전률(IFRS연결)        9016 non-null   float64
#  29  [제조]자기자본회전률(IFRS연결)       9016 non-null   float64
#  30  [제조]비유동자산회전률(IFRS연결)      9016 non-null   float64
#  31  [제조]재고자산회전률(IFRS연결)       9016 non-null   float64
#  32  [제조]매출채권회전률(IFRS연결)       9016 non-null   float64
#  33  [제조]매입채무회전률(IFRS연결)       9016 non-null   float64
#  34  [제조]매입채무회전기간(IFRS연결)      9016 non-null   float64
#  35  [제조]재고자산회전기간(IFRS연결)      9016 non-null   float64
#  36  [제조]매출채권회전기간(IFRS연결)      9016 non-null   float64
#  37  [제조]1회전기간(IFRS연결)         9016 non-null   float64
#  38  [제조]운전자본회전률(IFRS연결)       9016 non-null   float64
#  39  [제조]순운전자본회전률(IFRS연결)      9016 non-null   float64
#  40  [제조]유형자산회전율(IFRS연결)       9016 non-null   float64
#  41  [제조]유동자산회전률(IFRS연결)       9016 non-null   float64
#  42  [제조]당좌자산회전률(IFRS연결)       9016 non-null   float64
#  43  [제조]부가가치(IFRS연결)          9016 non-null   float64
#  44  [제조]총자본투자효율(IFRS연결)       9016 non-null   float64
#  45  [제조]설비투자효율(IFRS연결)        9016 non-null   float64
#  46  [제조]기계투자효율(IFRS연결)        9016 non-null   float64
#  47  [제조]부가가치율(IFRS연결)         9016 non-null   float64
#  48  [제조]노동소득분배율(IFRS연결)       9016 non-null   float64
#  49  [제조]자본분배율(IFRS연결)         9016 non-null   float64
#  50  [제조]이윤분배율(IFRS연결)         9016 non-null   float64
# dtypes: float64(48), int64(1), object(2)
# memory usage: 5.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14347 entries, 0 to 14346
# Data columns (total 55 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   회사명                       14347 non-null  object
#  1   거래소코드                     14347 non-null  int64
#  2   회계년도                      14347 non-null  object
#  3   상장일                       14347 non-null  object
#  4   상장폐지일                     1524 non-null   object
#  5   소속코드                      14347 non-null  int64
#  6   산업명                       14347 non-null  object
#  7   [제조]총자본증가율(IFRS연결)        9016 non-null   float64
#  8   [제조]유형자산증가율(IFRS연결)       9016 non-null   float64
#  9   [제조]비유동자산증가율(IFRS연결)      9016 non-null   float64
#  10  [제조]유동자산증가율(IFRS연결)       9016 non-null   float64
#  11  [제조]재고자산증가율(IFRS연결)       9016 non-null   float64
#  12  [제조]자기자본증가율(IFRS연결)       9016 non-null   float64
#  13  [제조]매출액증가율(IFRS연결)        9016 non-null   float64
#  14  [제조]순이익증가율(IFRS연결)        9016 non-null   float64
#  15  [제조]매출액총이익률(IFRS연결)       9016 non-null   float64
#  16  [제조]매출액순이익률(IFRS연결)       9016 non-null   float64
#  17  [제조]자기자본순이익률(IFRS연결)      9016 non-null   float64
#  18  [제조]총자본사업이익률(IFRS연결)      9016 non-null   float64
#  19  [제조]총자본순이익률(IFRS연결)       9016 non-null   float64
#  20  [제조]1주당매출액(IFRS연결)        9016 non-null   float64
#  21  [제조]1주당순이익(IFRS연결)        9016 non-null   float64
#  22  [제조]유동비율(IFRS연결)          9016 non-null   float64
#  23  [제조]당좌비율(IFRS연결)          9016 non-null   float64
#  24  [제조]현금비율(IFRS연결)          9016 non-null   float64
#  25  [제조]순운전자본비율(IFRS연결)       9016 non-null   float64
#  26  [제조]부채비율(IFRS연결)          9016 non-null   float64
#  27  [제조]이자보상배율(이자비용)(IFRS연결)  9016 non-null   float64
#  28  [제조]비유동비율(IFRS연결)         9016 non-null   float64
#  29  [제조]유동자산구성비율(IFRS연결)      9016 non-null   float64
#  30  [제조]자기자본구성비율(IFRS연결)      9016 non-null   float64
#  31  [제조]자기자본배율(IFRS연결)        9016 non-null   float64
#  32  [제조]총자본회전률(IFRS연결)        9016 non-null   float64
#  33  [제조]자기자본회전률(IFRS연결)       9016 non-null   float64
#  34  [제조]비유동자산회전률(IFRS연결)      9016 non-null   float64
#  35  [제조]재고자산회전률(IFRS연결)       9016 non-null   float64
#  36  [제조]매출채권회전률(IFRS연결)       9016 non-null   float64
#  37  [제조]매입채무회전률(IFRS연결)       9016 non-null   float64
#  38  [제조]매입채무회전기간(IFRS연결)      9016 non-null   float64
#  39  [제조]재고자산회전기간(IFRS연결)      9016 non-null   float64
#  40  [제조]매출채권회전기간(IFRS연결)      9016 non-null   float64
#  41  [제조]1회전기간(IFRS연결)         9016 non-null   float64
#  42  [제조]운전자본회전률(IFRS연결)       9016 non-null   float64
#  43  [제조]순운전자본회전률(IFRS연결)      9016 non-null   float64
#  44  [제조]유형자산회전율(IFRS연결)       9016 non-null   float64
#  45  [제조]유동자산회전률(IFRS연결)       9016 non-null   float64
#  46  [제조]당좌자산회전률(IFRS연결)       9016 non-null   float64
#  47  [제조]부가가치(IFRS연결)          9016 non-null   float64
#  48  [제조]총자본투자효율(IFRS연결)       9016 non-null   float64
#  49  [제조]설비투자효율(IFRS연결)        9016 non-null   float64
#  50  [제조]기계투자효율(IFRS연결)        9016 non-null   float64
#  51  [제조]부가가치율(IFRS연결)         9016 non-null   float64
#  52  [제조]노동소득분배율(IFRS연결)       9016 non-null   float64
#  53  [제조]자본분배율(IFRS연결)         9016 non-null   float64
#  54  [제조]이윤분배율(IFRS연결)         9016 non-null   float64
# dtypes: float64(48), int64(2), object(5)
# memory usage: 6.0+ MB
# 상장폐지 기업 수: 286
# C:\Users\성현태\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
